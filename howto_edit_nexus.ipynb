# %% [markdown]
# # How to edit a nexus file

# %% [markdown]
# Example on how to read a nexus file and create a new one based on its content.
# Here we take a GIXD scan with sensors and 2D pilatus images. We create a new nexus file with only a subset of the measurements. We also add compression to the data, which is very efficient to reduce the size of the file.

# %%
import h5py
import os
import numpy as np

original_file_name = 'original_nexus_files/SIRIUS_2020_03_12_0756.nxs'
new_file_name =  'modified_nexus_files/reduced_SIRIUS_2020_03_12_0756.nxs'

if os.path.exists(new_file_name):
    os.remove(new_file_name)

# %% [markdown]
# ## Read info from the original file

# %%
# Print all the datasets (:=leaves)
f = h5py.File(original_file_name, 'r')
for k0, v0 in f.items():
    print('%s'%k0)    
    for k1, v1 in v0.items():
        print('\t%s/%s'%(k0,k1))
        try:
            for k2, v2 in v1.items():
                print('\t\t%s/%s/%s'%(k0,k1,k2))
                try:
                    for k3, v3 in v2.items():
                        print('\t\t\t%s/%s/%s/%s'%(k0,k1,k2,k3))
                except:
                    pass
        except:
            pass
f.close()
# Out:
# root.spyc.DiffractoScanConfig
# 	root.spyc.DiffractoScanConfig/SIRIUS
# 		root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/energy
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/harmonic
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/mode
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/phase
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-c15-ei-c-hu36_energy/polarisation
# 		root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/current
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/function_mode
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/life_time
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/name
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/probe
# 			root.spyc.DiffractoScanConfig/SIRIUS/ans-ca-machinestatus/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_h.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c01-ex-fent_v.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c02-vi-jpen.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c02-vi-jpen.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c02-vi-jpen.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rs.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rs.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rs.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rs.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.2
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.2/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.2/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_rx.2/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_tx.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_tx.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_tx.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-op-mono2-mt_tx.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-vi-jpen.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-vi-jpen.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c03-vi-jpen.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_h.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-ex-fent_v.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-vi-jpen.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-vi-jpen.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c04-vi-jpen.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-op-fent_v.1-mt_d
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-op-fent_v.1-mt_d/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-op-fent_v.1-mt_d/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-op-fent_v.1-mt_d/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-vi-jpen.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-vi-jpen.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c05-vi-jpen.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.2
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.2/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.2/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-op-mir2-mt_c.2/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-vi-jaull.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-vi-jaull.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c06-vi-jaull.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_h.2/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-op-fent_v.2/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-vi-jaull.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-vi-jaull.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c07-vi-jaull.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.2
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.2/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.2/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-op-mir3-mt_c.2/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-vi-jaull.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-vi-jaull.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c08-vi-jaull.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c09-vi-jaull.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c09-vi-jaull.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c09-vi-jaull.1/type
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-att.1-mt_rs.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-att.1-mt_rs.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-att.1-mt_rs.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-att.1-mt_rs.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_h.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/device_name
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/gap
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/inside_up_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/outside_down_position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/position
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-fent_v.1/position_offset
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rx.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rx.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rx.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rx.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rz.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rz.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rz.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_rz.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_tz.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_tz.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_tz.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-ex-tab.1-mt_tz.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rs.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rs.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rs.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rs.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rx.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rx.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rx.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_rx.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tx.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tx.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tx.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tx.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tz.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tz.1/controller_record
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tz.1/offset
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-op-mir4-mt_tz.1/raw_value_pre
# 		root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-vi-jaull.1
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-vi-jaull.1/pressure
# 			root.spyc.DiffractoScanConfig/SIRIUS/i15-c-c10-vi-jaull.1/type
# 	root.spyc.DiffractoScanConfig/User
# 		root.spyc.DiffractoScanConfig/User/address
# 		root.spyc.DiffractoScanConfig/User/affiliation
# 		root.spyc.DiffractoScanConfig/User/mail
# 		root.spyc.DiffractoScanConfig/User/name
# 		root.spyc.DiffractoScanConfig/User/role
# 		root.spyc.DiffractoScanConfig/User/telephone_number
# 	root.spyc.DiffractoScanConfig/experiment_identifier
# 	root.spyc.DiffractoScanConfig/scan_config
# 		root.spyc.DiffractoScanConfig/scan_config/actuators_speed_control
# 		root.spyc.DiffractoScanConfig/scan_config/context_validation
# 		root.spyc.DiffractoScanConfig/scan_config/full name
# 		root.spyc.DiffractoScanConfig/scan_config/name
# 		root.spyc.DiffractoScanConfig/scan_config/type
# 		root.spyc.DiffractoScanConfig/scan_config/zig_zag
# 	root.spyc.DiffractoScanConfig/scan_data
# 		root.spyc.DiffractoScanConfig/scan_data/data_01
# 		root.spyc.DiffractoScanConfig/scan_data/data_02
# 		root.spyc.DiffractoScanConfig/scan_data/data_03
# 		root.spyc.DiffractoScanConfig/scan_data/data_04
# 		root.spyc.DiffractoScanConfig/scan_data/data_05
# 		root.spyc.DiffractoScanConfig/scan_data/data_06
# 		root.spyc.DiffractoScanConfig/scan_data/data_07
# 		root.spyc.DiffractoScanConfig/scan_data/data_08
# 		root.spyc.DiffractoScanConfig/scan_data/data_09
# 		root.spyc.DiffractoScanConfig/scan_data/data_10
# 		root.spyc.DiffractoScanConfig/scan_data/data_11
# 		root.spyc.DiffractoScanConfig/scan_data/data_12
# 		root.spyc.DiffractoScanConfig/scan_data/data_13
# 		root.spyc.DiffractoScanConfig/scan_data/integration_times
# 		root.spyc.DiffractoScanConfig/scan_data/sensors_rel_timestamps
# 		root.spyc.DiffractoScanConfig/scan_data/sensors_timestamps
# 	root.spyc.DiffractoScanConfig/title

# %% [markdown]
# Extract the names of the relevant leaves. Print their shape and type.

# %%
leaf_names = []
f = h5py.File(original_file_name, 'r')
for k0, v0 in f.items():
    for k1, v1 in v0.items():
        try:
            for k2, v2 in v1.items():
                if '%s'%k1 == 'scan_data':
                    leaf_names.append(k0+'/'+k1+'/'+k2)
        except:
            pass

for leaf in leaf_names:
    try:
        print('%s\nalias: %s\nshape: %s\ntype: %s\n'%(leaf, f[leaf].attrs['alias'], f[leaf].shape, f[leaf].dtype))
    except:
        print('%s\nlong_name: %s\nshape: %s\ntype: %s\n'%(leaf, f[leaf].attrs['long_name'], f[leaf].shape, f[leaf].dtype))
f.close()
# Out:
# root.spyc.DiffractoScanConfig/scan_data/data_01
# alias: b'delta'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_02
# alias: b'zs'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_03
# alias: b'gamma'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_04
# alias: b'hu36energy'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_05
# alias: b'xs'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_06
# alias: b'energydcm'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_07
# alias: b'current'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_08
# alias: b'mon2'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_09
# alias: b'surfacepressure'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_10
# alias: b'areapermolecule'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_11
# alias: b'qxy'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_12
# alias: b'pilatus'
# shape: (101, 1043, 981)
# type: int32
#
# root.spyc.DiffractoScanConfig/scan_data/data_13
# alias: b'pilatusroi1'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/integration_times
# long_name: b'integration_time'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/sensors_rel_timestamps
# long_name: b'sensorsRelTimestamps'
# shape: (101,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/sensors_timestamps
# long_name: b'sensorsTimestamps'
# shape: (101,)
# type: float64

# %% [markdown]
# ## Write the new file

# %% [markdown]
# Create a new file with only the interesting data (keep only a subset)

# %%
# limits of the subset to keep
imin = 20
imax = 100

with h5py.File(original_file_name,  "r") as r:
    with h5py.File(new_file_name,  "w") as w:

        for leaf in leaf_names:

            # create the subset
            new_data = r[leaf][...][imin:imax]

            # create a new dataset with the subset (without compression)
            #w.create_dataset(leaf, new_data.shape, dtype=new_data.dtype, data=new_data)
            
            # to add compression (very efficient!)
            w.create_dataset(leaf, new_data.shape, dtype=new_data.dtype, data=new_data, compression='gzip')

            for key in r[leaf].attrs.keys():
                w[leaf].attrs[key]=r[leaf].attrs[key]

# %% [markdown]
# ## Read info from the new file

# %% [markdown]
# Check the format of the new file.

# %%
# Print all the datasets (:=leaves)
f = h5py.File(new_file_name, 'r')

for k0, v0 in f.items():
    print('%s'%k0)    
    for k1, v1 in v0.items():
        print('\t%s/%s'%(k0,k1))
        try:
            for k2, v2 in v1.items():
                print('\t\t%s/%s/%s'%(k0,k1,k2))
                try:
                    for k3, v3 in v2.items():
                        print('\t\t\t%s/%s/%s/%s'%(k0,k1,k2,k3))
                except:
                    pass
        except:
            pass
f.close()
# Out:
# root.spyc.DiffractoScanConfig
# 	root.spyc.DiffractoScanConfig/scan_data
# 		root.spyc.DiffractoScanConfig/scan_data/data_01
# 		root.spyc.DiffractoScanConfig/scan_data/data_02
# 		root.spyc.DiffractoScanConfig/scan_data/data_03
# 		root.spyc.DiffractoScanConfig/scan_data/data_04
# 		root.spyc.DiffractoScanConfig/scan_data/data_05
# 		root.spyc.DiffractoScanConfig/scan_data/data_06
# 		root.spyc.DiffractoScanConfig/scan_data/data_07
# 		root.spyc.DiffractoScanConfig/scan_data/data_08
# 		root.spyc.DiffractoScanConfig/scan_data/data_09
# 		root.spyc.DiffractoScanConfig/scan_data/data_10
# 		root.spyc.DiffractoScanConfig/scan_data/data_11
# 		root.spyc.DiffractoScanConfig/scan_data/data_12
# 		root.spyc.DiffractoScanConfig/scan_data/data_13
# 		root.spyc.DiffractoScanConfig/scan_data/integration_times
# 		root.spyc.DiffractoScanConfig/scan_data/sensors_rel_timestamps
# 		root.spyc.DiffractoScanConfig/scan_data/sensors_timestamps

# %%
leaf_names = []
f = h5py.File(new_file_name, 'r')
for k0, v0 in f.items():
    for k1, v1 in v0.items():
        try:
            for k2, v2 in v1.items():
                if '%s'%k1 == 'scan_data':
                    leaf_names.append(k0+'/'+k1+'/'+k2)
        except:
            pass

for leaf in leaf_names:
    try:
        print('%s\nalias: %s\nshape: %s\ntype: %s\n'%(leaf, f[leaf].attrs['alias'], f[leaf].shape, f[leaf].dtype))
    except:
        print('%s\nlong_name: %s\nshape: %s\ntype: %s\n'%(leaf, f[leaf].attrs['long_name'], f[leaf].shape, f[leaf].dtype))
f.close()
# Out:
# root.spyc.DiffractoScanConfig/scan_data/data_01
# alias: b'delta'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_02
# alias: b'zs'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_03
# alias: b'gamma'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_04
# alias: b'hu36energy'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_05
# alias: b'xs'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_06
# alias: b'energydcm'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_07
# alias: b'current'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_08
# alias: b'mon2'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_09
# alias: b'surfacepressure'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_10
# alias: b'areapermolecule'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_11
# alias: b'qxy'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/data_12
# alias: b'pilatus'
# shape: (80, 1043, 981)
# type: int32
#
# root.spyc.DiffractoScanConfig/scan_data/data_13
# alias: b'pilatusroi1'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/integration_times
# long_name: b'integration_time'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/sensors_rel_timestamps
# long_name: b'sensorsRelTimestamps'
# shape: (80,)
# type: float64
#
# root.spyc.DiffractoScanConfig/scan_data/sensors_timestamps
# long_name: b'sensorsTimestamps'
# shape: (80,)
# type: float64

# %% [markdown]
# # Batch

# %% [markdown]
# We batch now a series of nexus files, adding compression to the data.

# %%
folder_to_compress = 'original_nexus_files'
folder_destination = 'modified_nexus_files'

if not os.path.exists(folder_destination):
    os.makedirs(folder_destination)

files = [file for file in os.listdir(folder_to_compress) if '.nxs' in file]

for file in files:
    old_file_path = folder_to_compress+'/'.join(file.split('/')[:-1])+'/'+file.split('/')[-1]
    new_file_path = folder_destination+'/'.join(file.split('/')[:-1])+'/'+file.split('/')[-1]

    leaf_names = []
    f = h5py.File(old_file_path, 'r')
    for k0, v0 in f.items():
        for k1, v1 in v0.items():
            try:
                for k2, v2 in v1.items():
                    if '%s'%k1 == 'scan_data':
                        leaf_names.append(k0+'/'+k1+'/'+k2)
            except:
                pass
    
    with h5py.File(old_file_path,  "r") as r:
        with h5py.File(new_file_path,  "w") as w:

            for leaf in leaf_names:

                # create the subset
                new_data = r[leaf][...]

                # to add compression (very efficient!)
                w.create_dataset(leaf, new_data.shape, dtype=new_data.dtype, data=new_data, compression='gzip')

                for key in r[leaf].attrs.keys():
                    w[leaf].attrs[key]=r[leaf].attrs[key]
